# %% [markdown]
# <a href="https://colab.research.google.com/github/sandrakaku/ml0930/blob/master/labelme_json_to_mask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import json
import numpy as np
import os

# %%
classes_name = ['background', 'dog', 'cat']
cls_map = {name: i for i, name in enumerate(classes_name)}
cls_map
# Out:
# {'background': 0, 'cat': 2, 'dog': 1}

# %%
img_path = '/content/drive/My Drive/class/勞動部/week9/anno_tools/labelme/img/1.jpg'
json_path = '/content/drive/My Drive/class/勞動部/week9/anno_tools/labelme/annotation/1.json'

# %%
img = cv2.imread(img_path)[:,:,::-1]
plt.imshow(img)

# %%
data = json.load(open(json_path))

# %%
data
# Out:
# {'flags': {},
#  'imageData': '...',
#  'imageHeight': 168,
#  'imagePath': '..\\img\\1.jpg',
#  'imageWidth': 300,
#  'shapes': [{'flags': {},
#    'group_id': None,
#    'label': 'dog',
#    'points': [[110.6837606837607, 32.31623931623932],
#     [91.45299145299145, 39.15384615384616],
#     [79.05982905982907, 53.25641025641026],
#     [80.34188034188034, 67.35897435897436],
#     [83.76068376068376, 75.90598290598291],
#     [75.21367521367522, 98.55555555555557],
#     [55.98290598290598, 112.23076923076925],
#     [14.529914529914532, 125.05128205128207],
#     [18.37606837606838, 137.8717948717949],
#     [63.24786324786325, 138.29914529914532],
#     [163.67521367521368, 137.8717948717949],
#     [156.4102564102564, 119.4957264957265],
#     [161.53846153846155, 101.54700854700855],
#     [161.53846153846155, 81.88888888888889],
#     [180.34188034188034, 89.15384615384616],
#     [197.00854700854703, 84.02564102564102],
#     [203.84615384615387, 90.86324786324786],
#     [216.66666666666669, 96.41880341880344],
#     [200.42735042735043, 75.47863247863248],
#     [170.94017094017096, 79.75213675213675],
#     [153.41880341880344, 78.89743589743591],
#     [149.14529914529916, 66.50427350427351],
#     [153.84615384615387, 52.82905982905983],
#     [132.05128205128207, 34.025641025641036]],
#    'shape_type': 'polygon'},
#   {'flags': {},
#    'group_id': None,
#    'label': 'cat',
#    'points': [[161.96581196581198, 85.30769230769232],
#     [162.82051282051282, 98.982905982906],
#     [158.11965811965814, 112.23076923076925],
#     [154.27350427350427, 122.4871794871795],
#     [163.24786324786325, 137.44444444444446],
#     [174.7863247863248, 137.8717948717949],
#     [206.4102564102564, 137.01709401709402],
#     [260.6837606837607, 137.01709401709402],
#     [298.71794871794873, 137.44444444444446],
#     [298.2905982905983, 128.47008547008548],
#     [264.52991452991455, 128.04273504273505],
#     [253.84615384615387, 114.7948717948718],
#     [234.61538461538464, 101.97435897435898],
#     [216.23931623931625, 100.26495726495727],
#     [203.41880341880344, 99.41025641025641],
#     [198.71794871794873, 92.5726495726496],
#     [201.2820512820513, 83.17094017094018],
#     [190.59829059829062, 86.16239316239316],
#     [174.7863247863248, 88.72649572649573],
#     [166.66666666666669, 87.87179487179489]],
#    'shape_type': 'polygon'}],
#  'version': '4.2.10'}

# %%
height = data['imageHeight']
width = data['imageWidth']

# %%
# Draw Object mask
mask = np.zeros((len(classes_name), height, width))
for shape in data['shapes']:
    cls_name = shape['label']
    cls_idx = cls_map[cls_name]
    points = shape['points']
    cv2.fillPoly(mask[cls_idx], np.array([points], dtype=np.int32), 255) # fill object with 255

for m in mask:
    plt.imshow(m, cmap='gray')
    plt.show()

# %%
# update backgroud mask
mask[0] = 255-np.max(mask[1:], axis=0)

# %%
# show all masks
for m in mask:
    plt.imshow(m, cmap='gray')
    plt.show()

# %%
# Get File name
filename_img = os.path.split(img_path)[-1]
filename = filename_img.split('.')[0]
filename
# Out:
# '1'

# %%
# Save Mask File
for i, m in enumerate(mask):
    path_save = os.path.join('/content/drive/My Drive', f'{filename}_mask_{i}.png')
    cv2.imwrite(path_save, m)
